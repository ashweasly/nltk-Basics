# %%
from nltk.tokenize import word_tokenize , sent_tokenize


Example_sentence = "Oh god beautiful Oh god Beautiful at the feet oh i do bow"

print word_tokenize(Example_sentence)
print sent_tokenize(Example_sentence)
# Out:
# ['Oh', 'god', 'beautiful', 'Oh', 'god', 'Beautiful', 'at', 'the', 'feet', 'oh', 'i', 'do', 'bow']
# ['Oh god beautiful Oh god Beautiful at the feet oh i do bow']

# %% [markdown]
# # sent_tokenize and word_tokenize
#
# sent_tokenize seperates the sentences
# word_tokenize seperates the words

# %% [markdown]
# # Stop Words
#
# It Catches only the noun,verb, and importent things

# %%
from nltk.tokenize import word_tokenize , sent_tokenize
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
Example_Text = "Appolo Medical Center and Hospital CTR MED SURG"
filter1 = []
words = word_tokenize(Example_Text)

filter1 = [i for i in words if not i in stop_words]
print word_tokenize(Example_Text)
print filter1
# Out:
# ['Appolo', 'Medical', 'Center', 'and', 'Hospital', 'CTR', 'MED', 'SURG']
# ['Appolo', 'Medical', 'Center', 'Hospital', 'CTR', 'MED', 'SURG']

# %% [markdown]
# # nltk Steeming
#
# Steeming the words like hosptial-->hospit

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()
new_text = "It is important to by very pythonly HOSP CTR SURGICAL you are pythoning with python. All pythoners have pythoned poorly at least once."
words = word_tokenize(new_text)

for w in words:
    print(ps.stem(w))
# Out:
# It
# is
# import
# to
# by
# veri
# pythonli
# hosp
# ctr
# surgic
# you
# are
# python
# with
# python
# .
# all
# python
# have
# python
# poorli
# at
# least
# onc
# .

# %% [markdown]
# # state union , Taging
#
# tagged the any given sentence like noun,verb,pronoun and etc..,

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
train_text = state_union.raw("2017-Gowtham.txt")
#sample_text = state_union.raw("2017-Gowtham.txt")
sample_text= "Appolo medical center Surgery Erode"
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)
def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()
# Out:
# [('Appolo', 'NNP'), ('medical', 'JJ'), ('center', 'NN'), ('Surgery', 'NNP'), ('Erode', 'NNP')]

# %% [raw]
# POS tag list:
#
# CC	coordinating conjunction
# CD	cardinal digit
# DT	determiner
# EX	existential there (like: "there is" ... think of it like "there exists")
# FW	foreign word
# IN	preposition/subordinating conjunction
# JJ	adjective	'big'
# JJR	adjective, comparative	'bigger'
# JJS	adjective, superlative	'biggest'
# LS	list marker	1)
# MD	modal	could, will
# NN	noun, singular 'desk'
# NNS	noun plural	'desks'
# NNP	proper noun, singular	'Harrison'
# NNPS	proper noun, plural	'Americans'
# PDT	predeterminer	'all the kids'
# POS	possessive ending	parent's
# PRP	personal pronoun	I, he, she
# PRP$	possessive pronoun	my, his, hers
# RB	adverb	very, silently,
# RBR	adverb, comparative	better
# RBS	adverb, superlative	best
# RP	particle	give up
# TO	to	go 'to' the store.
# UH	interjection	errrrrrrrm
# VB	verb, base form	take
# VBD	verb, past tense	took
# VBG	verb, gerund/present participle	taking
# VBN	verb, past participle	taken
# VBP	verb, sing. present, non-3d	take
# VBZ	verb, 3rd person sing. present	takes
# WDT	wh-determiner	which
# WP	wh-pronoun	who, what
# WP$	possessive wh-pronoun	whose
# WRB	wh-abverb	where, when

# %% [markdown]
# # nltk Chunking
# It is a group the Noun, Verb, Pronoun, and etc ..,

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
#sample_text = state_union.raw("2006-GWBush.txt")
sample_text = "Gowtham is become a software developer and he is working for whirldata"

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print chunked
            chunked.draw()     

    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S
#   (Chunk Gowtham/NNP)
#   is/VBZ
#   become/VBN
#   a/DT
#   software/NN
#   developer/NN
#   and/CC
#   he/PRP
#   is/VBZ
#   working/VBG
#   for/IN
#   whirldata/NN)

# %% [markdown]
# # nltk Chinking
#
# It is a seperate the Noun, Verb, Pronoun, and etc ..,

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
#sample_text = "Gowtham is become a software developer and he is working for whirldata, Gowtham is hobbies are playing large console games"

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[5:]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)

            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""

            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print chunked
            chunked.draw()

    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S (Chunk 31/CD ,/, 2006/CD ./.))
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP DraperEvery/NNP time/NN I/PRP)
#   'm/VBP
#   (Chunk invited/JJ)
#   to/TO
#   this/DT
#   (Chunk rostrum/NN ,/, I/PRP)
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   (Chunk privilege/NN ,/, and/CC mindful/NN)
#   of/IN
#   the/DT
#   (Chunk history/NN we/PRP)
#   've/VBP
#   seen/VBN
#   (Chunk together/RB ./.))
# (S
#   (Chunk We/PRP)
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chunk Capitol/NNP dome/NN)
#   in/IN
#   (Chunk moments/NNS)
#   of/IN
#   (Chunk
#     national/JJ
#     mourning/NN
#     and/CC
#     national/JJ
#     achievement/NN
#     ./.))
# (S
#   (Chunk We/PRP)
#   have/VBP
#   served/VBN
#   (Chunk America/NNP)
#   through/IN
#   (Chunk one/CD)
#   of/IN
#   the/DT
#   (Chunk most/RBS consequential/JJ periods/NNS)
#   of/IN
#   (Chunk our/PRP$ history/NN --/: and/CC it/PRP)
#   has/VBZ
#   been/VBN
#   (Chunk my/PRP$ honor/NN)
# ...

# %% [markdown]
# # Named Entity

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[5:]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            namedEnt = nltk.ne_chunk(tagged, binary=True)
            namedEnt.draw()
    except Exception as e:
        print(str(e))


process_content()

# %% [markdown]
# # Lemmatizer
#
# Changing the Plural to Singular & Verb + ing --> Verb

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("calves"))
print(lemmatizer.lemmatize("thieves"))
print(lemmatizer.lemmatize("pythons"))
print(lemmatizer.lemmatize("better", pos="a"))
print(lemmatizer.lemmatize("best", pos="a"))
print(lemmatizer.lemmatize("badder",pos="a"))
print(lemmatizer.lemmatize("working",'v'))
print(lemmatizer.lemmatize("changing",'v'))
# Out:
# cat
# cactus
# calf
# thief
# python
# good
# best
# badder
# work
# change
